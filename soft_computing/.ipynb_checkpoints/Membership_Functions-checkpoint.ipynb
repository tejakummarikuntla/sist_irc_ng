# %%
# !pip install scikit-fuzzy

# %%
# Triangular Membership function 
import numpy as np
import skfuzzy as sk
import matplotlib.pyplot as plt

x_qual = np.arange(0, 11, 1)
qual_lo = sk.trimf(x_qual, [0, 0, 5])

# %%
# Trapezoidal Membership functions
qual_lo = sk.trapmf(x_qual, [0, 0, 5, 5])

# %%
# Gausssian Membership functions
qual_lo = sk.gaussmf(x_qual, np.mean(x_qual), np.std(x_qual))

# %%
# Generalized bell membership functuions
qual_lo = sk.gbellmf(x_qual, 0.5, 0.5, 0.5)

# %%
# Sigmoid Membership function
qual_lo = sk.sigmf(x_qual, 0.5, 0.5)

# %%
x = np.arange(30, 80, 0.1)

# %%
x
# Out:
# array([30. , 30.1, 30.2, 30.3, 30.4, 30.5, 30.6, 30.7, 30.8, 30.9, 31. ,
#        31.1, 31.2, 31.3, 31.4, 31.5, 31.6, 31.7, 31.8, 31.9, 32. , 32.1,
#        32.2, 32.3, 32.4, 32.5, 32.6, 32.7, 32.8, 32.9, 33. , 33.1, 33.2,
#        33.3, 33.4, 33.5, 33.6, 33.7, 33.8, 33.9, 34. , 34.1, 34.2, 34.3,
#        34.4, 34.5, 34.6, 34.7, 34.8, 34.9, 35. , 35.1, 35.2, 35.3, 35.4,
#        35.5, 35.6, 35.7, 35.8, 35.9, 36. , 36.1, 36.2, 36.3, 36.4, 36.5,
#        36.6, 36.7, 36.8, 36.9, 37. , 37.1, 37.2, 37.3, 37.4, 37.5, 37.6,
#        37.7, 37.8, 37.9, 38. , 38.1, 38.2, 38.3, 38.4, 38.5, 38.6, 38.7,
#        38.8, 38.9, 39. , 39.1, 39.2, 39.3, 39.4, 39.5, 39.6, 39.7, 39.8,
#        39.9, 40. , 40.1, 40.2, 40.3, 40.4, 40.5, 40.6, 40.7, 40.8, 40.9,
#        41. , 41.1, 41.2, 41.3, 41.4, 41.5, 41.6, 41.7, 41.8, 41.9, 42. ,
#        42.1, 42.2, 42.3, 42.4, 42.5, 42.6, 42.7, 42.8, 42.9, 43. , 43.1,
#        43.2, 43.3, 43.4, 43.5, 43.6, 43.7, 43.8, 43.9, 44. , 44.1, 44.2,
# ...

# %%
slow = sk.trimf(x, [30, 30, 50])

# %%
slow
# Out:
# array([1.   , 0.995, 0.99 , 0.985, 0.98 , 0.975, 0.97 , 0.965, 0.96 ,
#        0.955, 0.95 , 0.945, 0.94 , 0.935, 0.93 , 0.925, 0.92 , 0.915,
#        0.91 , 0.905, 0.9  , 0.895, 0.89 , 0.885, 0.88 , 0.875, 0.87 ,
#        0.865, 0.86 , 0.855, 0.85 , 0.845, 0.84 , 0.835, 0.83 , 0.825,
#        0.82 , 0.815, 0.81 , 0.805, 0.8  , 0.795, 0.79 , 0.785, 0.78 ,
#        0.775, 0.77 , 0.765, 0.76 , 0.755, 0.75 , 0.745, 0.74 , 0.735,
#        0.73 , 0.725, 0.72 , 0.715, 0.71 , 0.705, 0.7  , 0.695, 0.69 ,
#        0.685, 0.68 , 0.675, 0.67 , 0.665, 0.66 , 0.655, 0.65 , 0.645,
#        0.64 , 0.635, 0.63 , 0.625, 0.62 , 0.615, 0.61 , 0.605, 0.6  ,
#        0.595, 0.59 , 0.585, 0.58 , 0.575, 0.57 , 0.565, 0.56 , 0.555,
#        0.55 , 0.545, 0.54 , 0.535, 0.53 , 0.525, 0.52 , 0.515, 0.51 ,
#        0.505, 0.5  , 0.495, 0.49 , 0.485, 0.48 , 0.475, 0.47 , 0.465,
#        0.46 , 0.455, 0.45 , 0.445, 0.44 , 0.435, 0.43 , 0.425, 0.42 ,
# ...

# %%
medium = sk.trimf(x, [30, 50, 70])
medium
# Out:
# array([0.   , 0.005, 0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035, 0.04 ,
#        0.045, 0.05 , 0.055, 0.06 , 0.065, 0.07 , 0.075, 0.08 , 0.085,
#        0.09 , 0.095, 0.1  , 0.105, 0.11 , 0.115, 0.12 , 0.125, 0.13 ,
#        0.135, 0.14 , 0.145, 0.15 , 0.155, 0.16 , 0.165, 0.17 , 0.175,
#        0.18 , 0.185, 0.19 , 0.195, 0.2  , 0.205, 0.21 , 0.215, 0.22 ,
#        0.225, 0.23 , 0.235, 0.24 , 0.245, 0.25 , 0.255, 0.26 , 0.265,
#        0.27 , 0.275, 0.28 , 0.285, 0.29 , 0.295, 0.3  , 0.305, 0.31 ,
#        0.315, 0.32 , 0.325, 0.33 , 0.335, 0.34 , 0.345, 0.35 , 0.355,
#        0.36 , 0.365, 0.37 , 0.375, 0.38 , 0.385, 0.39 , 0.395, 0.4  ,
#        0.405, 0.41 , 0.415, 0.42 , 0.425, 0.43 , 0.435, 0.44 , 0.445,
#        0.45 , 0.455, 0.46 , 0.465, 0.47 , 0.475, 0.48 , 0.485, 0.49 ,
#        0.495, 0.5  , 0.505, 0.51 , 0.515, 0.52 , 0.525, 0.53 , 0.535,
#        0.54 , 0.545, 0.55 , 0.555, 0.56 , 0.565, 0.57 , 0.575, 0.58 ,
# ...

# %%
medium_fast = sk.trimf(x, [50, 60, 80])
medium_fast
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
full_speed = sk.trimf(x, [60, 80, 80])
full_speed
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
plt.figure()
plt.plot(x, full_speed, 'b', linewidth=1.5, label='Full Speed')
plt.plot(x, medium_fast, 'k', linewidth=1.5, label='Medium Fast')
plt.plot(x, medium, 'm', linewidth=1.5, label='Medium Powered')
plt.plot(x, slow, 'r', linewidth=1.5, label='Slow')
plt.title('Penalty Kick Fuzzy')
plt.ylabel('Membership')
plt.xlabel("Speed (Miles Per Hour)")
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5),
ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# ## Trapezoidal Membership Functions

# %%
#Defining the Fuzzy Range from a speed of 30 to 90
x = np.arange(30, 90, 0.1)
#Defining the trapezoidal membership functions
slow = sk.trapmf(x, [20, 30, 30, 50])
medium = sk.trapmf(x, [30, 50, 50, 70])
medium_fast = sk.trapmf(x, [50, 60, 60, 80])
full_speed = sk.trapmf(x, [60, 80, 80, 90])
#Plotting the Membership Functions Defined
plt.figure()
plt.plot(x, full_speed, 'b', linewidth=1.5, label='Full Speed')
plt.plot(x, medium_fast, 'k', linewidth=1.5, label='Medium Fast')
plt.plot(x, medium, 'm', linewidth=1.5, label='Medium Powered')
plt.plot(x, slow, 'r', linewidth=1.5, label='Slow')
plt.title('Penalty Kick Fuzzy')
plt.ylabel('Membership')
plt.xlabel("Speed (Miles Per Hour)")
plt.legend(loc='center right', bbox_to_anchor=(1.25, 0.5),
ncol=1, fancybox=True, shadow=True)

# %% [markdown]
# ## Gaussian Membership Function
